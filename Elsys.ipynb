# %% [markdown]
# <a href="https://colab.research.google.com/github/henrique-tn/Elsys/blob/main/Elsys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalando pacotes

# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Leitura do Dataset

# %%
df = pd.read_excel("/DataSet.xlsx")

# %%
df.head()
# Out:
#    Ano Mês  Base Assinantes Banda Larga           Cidade Estado  \
# 0  2024/06                            0  Abadia de Goiás     GO
# 1  2024/06                            6  Abadia de Goiás     GO
# 2  2024/06                            8  Abadia de Goiás     GO
# 3  2024/06                            2  Abadia de Goiás     GO
# 4  2024/06                           31  Abadia de Goiás     GO
#
#                                Nome Operadora Tecnologia       Velocidade
# 0      HUGHES TELECOMUNICACOES DO BRASIL LTDA       VSAT         > 34Mbps
# 1      HUGHES TELECOMUNICACOES DO BRASIL LTDA       VSAT  12Mbps a 34Mbps
# 2      HUGHES TELECOMUNICACOES DO BRASIL LTDA       VSAT   2Mbps a 12Mbps
# 3      HUGHES TELECOMUNICACOES DO BRASIL LTDA       VSAT  512kbps a 2Mbps
# 4  STARLINK BRAZIL SERVICOS DE INTERNET LTDA.       VSAT         > 34Mbps

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201592 entries, 0 to 201591
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Ano Mês                      201592 non-null  object
#  1   Base Assinantes Banda Larga  201592 non-null  int64
#  2   Cidade                       201592 non-null  object
#  3   Estado                       201592 non-null  object
#  4   Nome Operadora               201592 non-null  object
#  5   Tecnologia                   201592 non-null  object
#  6   Velocidade                   201592 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 10.8+ MB
